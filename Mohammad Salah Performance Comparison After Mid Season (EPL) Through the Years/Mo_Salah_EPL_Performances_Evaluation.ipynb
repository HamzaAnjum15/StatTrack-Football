# %% [markdown]
# <a href="https://colab.research.google.com/github/HamzaAnjum15/StatTrack-Football/blob/main/Mohammad%20Salah%20Performance%20Comparison%20After%20Mid%20Season%20(EPL)%20Through%20the%20Years/Mo_Salah_EPL_Performances_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO

# Data taken from TransferMarkt
data = {
    'Season': ['2017/18', '2018/19', '2019/20', '2020/21', '2021/22', '2022/23','2023/24','2024/25'],
    'Goals': [15, 12, 9, 13, 15, 7, 12, 17],
    'Assists': [3, 6, 4, 3, 9, 4, 7, 13]
}
df = pd.DataFrame(data)

# Create the line plot
plt.figure(figsize=(12, 6))
plt.style.use('dark_background')  # Set dark background

# Plot goals and assists
plt.plot(df['Season'], df['Goals'], marker='o', color='gold', label='Goals', linewidth=2)
plt.plot(df['Season'], df['Assists'], marker='o', color='cyan', label='Assists', linewidth=2)

# Add title and labels
plt.title("Mohamed Salah - Goals and Assists in EPL Seasons (Liverpool)", fontsize=16, color='white')
plt.xlabel("Season", fontsize=12, color='white')
plt.ylabel("Count", fontsize=12, color='white')

# Customize ticks
plt.xticks(color='white', fontsize=10)
plt.yticks(color='white', fontsize=10)

# Add grid
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

# Add legend
plt.legend(loc='upper left', fontsize=10, facecolor='black', edgecolor='white', framealpha=0.9)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Place the image to the right of the plot
plt.figimage(img.resize((170, 220)), xo=1040, yo=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO

# Data taken from TransferMarkt
seasons = ['2017/18', '2018/19', '2019/20', '2020/21', '2021/22', '2022/23','2023/24','2024/25'],
goals = [15, 12, 9, 13, 15, 7, 12, 17],
assists = [3, 6, 4, 3, 9, 4, 7, 13]

# Creating the plot
plt.style.use("dark_background")
fig, ax = plt.subplots(figsize=(12, 8))

# Plotting Goals and Assists
ax.plot(seasons, goals, label="Goals", marker="o", color="gold", linewidth=2)
ax.plot(seasons, assists, label="Assists", marker="o", color="cyan", linewidth=2)

# Adding text annotations
for i, (season, goal, assist) in enumerate(zip(seasons, goals, assists)):
    ax.text(i, goal + 1, str(goal), color="gold", fontsize=12, ha="center")
    ax.text(i, assist - 1, str(assist), color="cyan", fontsize=12, ha="center")

# Customizing the plot
ax.set_title("Mohamed Salah's Goals and Assists per EPL Season", fontsize=16, color="white")
ax.set_xlabel("Season", fontsize=14, color="white")
ax.set_ylabel("Count", fontsize=14, color="white")
ax.legend(loc="upper right", fontsize=12)
ax.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.5)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))
mg = Image.open(BytesIO(response.content))

image_box = OffsetImage(img, zoom=0.2)  # Adjust the zoom level
annotation = AnnotationBbox(image_box, (5.5, max(goals) - 2), frameon=False)
ax.add_artist(annotation)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-679810282ff8> in <cell line: 17>()
#      15
#      16 # Plotting Goals and Assists
# ---> 17 ax.plot(seasons, goals, label="Goals", marker="o", color="gold", linewidth=2)
#      18 ax.plot(seasons, assists, label="Assists", marker="o", color="cyan", linewidth=2)
#      19
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1719         """
#    1720         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722         for line in lines:
#    1723             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, *args, **kwargs)
#     301                 this += args[0],
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO

# Data from TransferMarkt
data = {
    'Season': ['2017/18', '2018/19', '2019/20', '2020/21', '2021/22', '2022/23', '2023/24', '2024/25'],
    'Goals': [15, 12, 9, 13, 15, 7, 12, 17],
    'Assists': [3, 6, 4, 3, 9, 4, 7, 13]
}
df = pd.DataFrame(data)

# Create the plot
plt.figure(figsize=(14, 7))
plt.style.use('dark_background')  # Set dark background

# Plot goals and assists
plt.plot(df['Season'], df['Goals'], marker='o', color='gold', label='Goals', linewidth=2)
plt.plot(df['Season'], df['Assists'], marker='o', color='cyan', label='Assists', linewidth=2)

# Annotate data points with values
for i, (season, goal, assist) in enumerate(zip(df['Season'], df['Goals'], df['Assists'])):
    plt.text(i, goal + 0.5, str(goal), color='gold', fontsize=10, ha='center')
    plt.text(i, assist - 0.5, str(assist), color='cyan', fontsize=10, ha='center')

# Add title and labels
plt.title("Mohamed Salah - Goals and Assists in EPL Seasons (Liverpool)", fontsize=18, color='white')
plt.xlabel("Season", fontsize=14, color='white')
plt.ylabel("Count", fontsize=14, color='white')

# Customize ticks
plt.xticks(color='white', fontsize=12)
plt.yticks(color='white', fontsize=12)

# Add grid and legend
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.legend(loc='upper left', fontsize=12, facecolor='black', edgecolor='white', framealpha=0.9)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Use OffsetImage for better control
image_box = OffsetImage(img.resize((170, 220)), zoom=1, resample=True)
annotation = AnnotationBbox(image_box, (7.5, max(df['Goals']) - 2), frameon=False, pad=0.5)
plt.gca().add_artist(annotation)

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO

# Data from TransferMarkt
data = {
    'Season': ['2017/18', '2018/19', '2019/20', '2020/21', '2021/22', '2022/23', '2023/24', '2024/25'],
    'Goals': [15, 12, 9, 13, 15, 7, 12, 17],
    'Assists': [3, 6, 4, 3, 9, 4, 7, 13]
}
df = pd.DataFrame(data)

# Create the plot
plt.figure(figsize=(14, 7))
plt.style.use('dark_background')  # Set dark background

# Plot goals and assists
plt.plot(df['Season'], df['Goals'], marker='o', color='gold', label='Goals', linewidth=2)
plt.plot(df['Season'], df['Assists'], marker='o', color='cyan', label='Assists', linewidth=2)

# Annotate data points with values
for i, (season, goal, assist) in enumerate(zip(df['Season'], df['Goals'], df['Assists'])):
    plt.text(i, goal + 0.5, str(goal), color='gold', fontsize=10, ha='center')
    plt.text(i, assist - 0.5, str(assist), color='cyan', fontsize=10, ha='center')

# Add title and labels
plt.title("Mohamed Salah - Goals and Assists in EPL Seasons (Liverpool)", fontsize=18, color='white')
plt.xlabel("Season", fontsize=14, color='white')
plt.ylabel("Count", fontsize=14, color='white')

# Customize ticks
plt.xticks(color='white', fontsize=12)
plt.yticks(color='white', fontsize=12)

# Add grid and legend
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.legend(loc='upper left', fontsize=12, facecolor='black', edgecolor='white', framealpha=0.9)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"  # New verified URL
try:
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    # Use OffsetImage for better control
    image_box = OffsetImage(img.resize((120, 160)), zoom=1, resample=True)
    annotation = AnnotationBbox(image_box, (7.5, max(df['Goals']) - 2), frameon=False, pad=0.5)
    plt.gca().add_artist(annotation)
except Exception as e:
    print(f"Error loading image: {e}")

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO

# Data from TransferMarkt
data = {
    'Season': ['2017/18', '2018/19', '2019/20', '2020/21', '2021/22', '2022/23', '2023/24', '2024/25'],
    'Goals': [15, 12, 9, 13, 15, 7, 12, 17],
    'Assists': [3, 6, 4, 3, 9, 4, 7, 13]
}
df = pd.DataFrame(data)

# Create the plot
plt.figure(figsize=(14, 7))
plt.style.use('dark_background')  # Set dark background

# Plot goals and assists
plt.plot(df['Season'], df['Goals'], marker='o', color='gold', label='Goals', linewidth=2)
plt.plot(df['Season'], df['Assists'], marker='o', color='cyan', label='Assists', linewidth=2)

# Annotate data points with values
for i, (season, goal, assist) in enumerate(zip(df['Season'], df['Goals'], df['Assists'])):
    plt.text(i, goal + 0.5, str(goal), color='gold', fontsize=10, ha='center')
    plt.text(i, assist - 0.5, str(assist), color='cyan', fontsize=10, ha='center')

# Add title and labels
plt.title("Mohamed Salah - Goals and Assists in EPL Seasons (Liverpool)", fontsize=18, color='white')
plt.xlabel("Season", fontsize=14, color='white')
plt.ylabel("Count", fontsize=14, color='white')

# Customize ticks
plt.xticks(color='white', fontsize=12)
plt.yticks(color='white', fontsize=12)

# Add grid and legend
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.legend(loc='upper left', fontsize=12, facecolor='black', edgecolor='white', framealpha=0.9)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"
try:
    response = requests.get(image_url, stream=True)
    response.raise_for_status()  # Raise HTTP errors if any
    img = Image.open(BytesIO(response.content))
    # Use OffsetImage for better control
    image_box = OffsetImage(img.resize((120, 160)), zoom=1, resample=True)
    annotation = AnnotationBbox(image_box, (7.5, max(df['Goals']) - 2), frameon=False, pad=0.5)
    plt.gca().add_artist(annotation)
except Exception as e:
    print(f"Error loading image: {e}")

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO

# Data from TransferMarkt
data = {
    'Season': ['2017/18', '2018/19', '2019/20', '2020/21', '2021/22', '2022/23', '2023/24', '2024/25'],
    'Goals': [15, 12, 9, 13, 15, 7, 12, 17],
    'Assists': [3, 6, 4, 3, 9, 4, 7, 13]
}
df = pd.DataFrame(data)

# Create the plot
plt.figure(figsize=(14, 7))
plt.style.use('dark_background')  # Set dark background

# Plot goals and assists
plt.plot(df['Season'], df['Goals'], marker='o', color='red', label='Goals', linewidth=2)
plt.plot(df['Season'], df['Assists'], marker='o', color='gold', label='Assists', linewidth=2)

# Annotate data points with values
# for i, (season, goal, assist) in enumerate(zip(df['Season'], df['Goals'], df['Assists'])):
#     plt.text(i, goal + 0.5, str(goal), color='red', fontsize=10, ha='center')
#     plt.text(i, assist - 0.5, str(assist), color='gold', fontsize=10, ha='center')


# Add title and labels
plt.title("Mo Salah's Premier League Performances After Half a Season(Liverpool): A Comparison Through the Years", fontsize=18, color='white')
plt.xlabel("Season", fontsize=14, color='white')
plt.ylabel("Count", fontsize=14, color='white')

# Customize ticks
plt.xticks(color='white', fontsize=12)
plt.yticks(color='white', fontsize=12)

# Add grid and legend
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.legend(loc='upper left', fontsize=12, facecolor='black', edgecolor='white', framealpha=0.9)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Display image on the right side of the plot
plt.figimage(img.resize((230, 295)), xo=1200, yo=75)

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Create the plot
plt.figure(figsize=(14, 7))
plt.style.use('dark_background')  # Set dark background

# Plot goals and assists
plt.plot(df['Season'], df['Goals'], marker='o', color='red', label='Goals', linewidth=2)
plt.plot(df['Season'], df['Assists'], marker='o', color='gold', label='Assists', linewidth=2)

# Annotate data points with values
for i, (season, goal, assist) in enumerate(zip(df['Season'], df['Goals'], df['Assists'])):
    plt.text(i, goal + 0.5, str(goal), color='red', fontsize=10, ha='center')
    plt.text(i, assist - 0.65, str(assist), color='gold', fontsize=10, ha='center')

# Add title and labels
plt.title("Mo Salah's Premier League Performances After Half a Season(Liverpool): A Comparison Through the Years", fontsize=18, color='white')
plt.xlabel("Season", fontsize=14, color='white')
plt.ylabel("Count", fontsize=14, color='white')

# Customize ticks
plt.xticks(color='white', fontsize=12)
plt.yticks(color='white', fontsize=12)

# Adjust y-axis limits to provide more space at the top
plt.ylim(0, max(df['Goals']) + 2)  # Increase the upper limit slightly (add 2)

# Add grid and legend
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.legend(loc='upper left', fontsize=12, facecolor='black', edgecolor='white', framealpha=0.9)

# Add Mohamed Salah's image
image_url = "https://backend.liverpoolfc.com/sites/default/files/styles/lg/public/2024-08/mohamed-salah-alternative-body-v2-2024.png?itok=VMLtOKVH"
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Display image on the right side of the plot
plt.figimage(img.resize((230, 295)), xo=1179, yo=63)
# Adjust layout and show plot
plt.tight_layout()

plt.show()

# %%
from google.colab import files
files.download('mo_salah_performance_plot.png')
