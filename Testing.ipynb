# %% [markdown]
# <a href="https://colab.research.google.com/github/HamzaAnjum15/StatTrack-Football/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install statsbombpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from statsbombpy import sb

# %%
comp = sb.competitions()
comp
# Out:
# /usr/local/lib/python3.10/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# ...

# %%
sb.matches(competition_id=9, season_id=281)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off              competition     season  \
# 0    3895302  2024-04-14  17:30:00.000  Germany - 1. Bundesliga  2023/2024
# 1    3895292  2024-04-06  15:30:00.000  Germany - 1. Bundesliga  2023/2024
# 2    3895333  2024-05-05  18:30:00.000  Germany - 1. Bundesliga  2023/2024
# 3    3895340  2024-05-12  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# 4    3895348  2024-05-18  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 5    3895286  2024-03-30  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 6    3895220  2024-02-03  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 7    3895250  2024-02-23  21:30:00.000  Germany - 1. Bundesliga  2023/2024
# 8    3895266  2024-03-10  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# ...

# %%
sb.matches(competition_id=55, season_id=43)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off         competition season  \
# 0    3795108  2021-07-02  18:00:00.000  Europe - UEFA Euro   2020
# 1    3788769  2021-06-21  21:00:00.000  Europe - UEFA Euro   2020
# 2    3788766  2021-06-20  18:00:00.000  Europe - UEFA Euro   2020
# 3    3795220  2021-07-06  21:00:00.000  Europe - UEFA Euro   2020
# 4    3788761  2021-06-18  15:00:00.000  Europe - UEFA Euro   2020
# 5    3788764  2021-06-19  18:00:00.000  Europe - UEFA Euro   2020
# 6    3788773  2021-06-23  21:00:00.000  Europe - UEFA Euro   2020
# 7    3788755  2021-06-16  18:00:00.000  Europe - UEFA Euro   2020
# 8    3788754  2021-06-16  21:00:00.000  Europe - UEFA Euro   2020
# 9    3788762  2021-06-19  21:00:00.000  Europe - UEFA Euro   2020
# 10   3788760  2021-06-18  18:00:00.000  Europe - UEFA Euro   2020
# ...

# %%
ucl = comp[comp['competition_name'] == 'Champions League']
ucl
# Out:
#     competition_id  season_id country_name  competition_name  \
# 3               16          4       Europe  Champions League
# 4               16          1       Europe  Champions League
# 5               16          2       Europe  Champions League
# 6               16         27       Europe  Champions League
# 7               16         26       Europe  Champions League
# 8               16         25       Europe  Champions League
# 9               16         24       Europe  Champions League
# 10              16         23       Europe  Champions League
# 11              16         22       Europe  Champions League
# 12              16         21       Europe  Champions League
# 13              16         41       Europe  Champions League
# 14              16         39       Europe  Champions League
# 15              16         37       Europe  Champions League
# 16              16         44       Europe  Champions League
# ...

# %%
sb.matches(competition_id=16, season_id=276)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                competition     season  \
# 0   3888711  1971-06-02  22:45:00.000  Europe - Champions League  1970/1971
#
#   home_team      away_team  home_score  away_score match_status  ...  \
# 0      Ajax  Panathinaikos           2           0    available  ...
#
#   last_updated_360 match_week competition_stage          stadium      referee  \
# 0             None          1             Final  Wembley Stadium  Jack Taylor
#
#    home_managers  away_managers data_version shot_fidelity_version  \
# 0  Rinus Michels  Ferenc Puskás        1.1.0                     2
#
#   xy_fidelity_version
# 0                   2
#
# [1 rows x 22 columns]
